# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Downloads\\Python Office'

# %%
df = pd.read_csv("apple_products.csv")

# %% [markdown]
# ### Importing Data

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %% [markdown]
# ### Performing EDA

# %%
df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
df.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
df.dropna()
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df['Product Name'].value_counts().head(10)
# Out:
# Product Name
# APPLE iPhone 8 Plus (Gold, 64 GB)             1
# APPLE iPhone 12 Pro (Pacific Blue, 128 GB)    1
# APPLE iPhone 12 Mini (Black, 128 GB)          1
# APPLE iPhone 12 Mini (Blue, 128 GB)           1
# APPLE iPhone 12 (Black, 128 GB)               1
# APPLE iPhone 12 (Blue, 128 GB)                1
# APPLE iPhone 12 Pro Max (Silver, 128 GB)      1
# APPLE iPhone 12 Mini (Red, 64 GB)             1
# APPLE iPhone 12 Pro Max (Gold, 128 GB)        1
# APPLE iPhone 12 (Green, 128 GB)               1
# Name: count, dtype: int64

# %%
df["Product Name"].value_counts()
# Out:
# Product Name
# APPLE iPhone 8 Plus (Gold, 64 GB)                 1
# APPLE iPhone 12 Pro (Pacific Blue, 128 GB)        1
# APPLE iPhone 12 Mini (Black, 128 GB)              1
# APPLE iPhone 12 Mini (Blue, 128 GB)               1
# APPLE iPhone 12 (Black, 128 GB)                   1
#                                                  ..
# APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)    1
# APPLE iPhone 12 Mini (White, 128 GB)              1
# APPLE iPhone 12 Pro (Graphite, 256 GB)            1
# APPLE iPhone 12 Mini (White, 64 GB)               1
# APPLE iPhone 11 (Red, 64 GB)                      1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ### Iphone With the Biggest RAM

# %%
#TOP 5 IPHONES WITH THE BIGGEST RAM
df[["Ram","Product Name","Brand"]].sort_values(ascending=False,by='Ram',ignore_index=True)[:20]
# Out:
#      Ram                                    Product Name  Brand
# 0   6 GB      APPLE iPhone 12 Pro Max (Graphite, 256 GB)  Apple
# 1   6 GB                   APPLE iPhone 12 (Red, 128 GB)  Apple
# 2   6 GB      APPLE iPhone 12 Pro Max (Graphite, 128 GB)  Apple
# 3   6 GB          APPLE iPhone 12 Pro (Graphite, 256 GB)  Apple
# 4   6 GB  APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)  Apple
# 5   6 GB                 APPLE iPhone 12 (Black, 128 GB)  Apple
# 6   6 GB                  APPLE iPhone 12 (Blue, 128 GB)  Apple
# 7   6 GB        APPLE iPhone 12 Pro Max (Silver, 128 GB)  Apple
# 8   6 GB               APPLE iPhone 12 Mini (Red, 64 GB)  Apple
# 9   6 GB          APPLE iPhone 12 Pro Max (Gold, 128 GB)  Apple
# 10  6 GB                 APPLE iPhone 12 (Green, 128 GB)  Apple
# 11  6 GB                  APPLE iPhone 12 (White, 64 GB)  Apple
# 12  6 GB          APPLE iPhone 12 Pro (Graphite, 128 GB)  Apple
# 13  6 GB                  APPLE iPhone 12 (Black, 64 GB)  Apple
# ...

# %% [markdown]
# ### Iphone With Lowest RAM

# %%
#LAST 5 IPHONES WITH THE LEAST RAM
df[["Ram","Product Name"]].sort_values(ascending=True,by="Ram",ignore_index=True)[:5]
# Out:
#     Ram                              Product Name
# 0  2 GB         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  2 GB  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2  2 GB      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3  2 GB           APPLE iPhone 8 (Silver, 256 GB)
# 4  2 GB             APPLE iPhone 8 (Gold, 256 GB)

# %% [markdown]
# ### Numbers of Rating

# %%
#TOP 5 HIGHEST RATING
df[["Number Of Ratings","Product Name","Brand"]].sort_values(ascending=False,by="Number Of Ratings",ignore_index=True)[:5]
# Out:
#    Number Of Ratings                                       Product Name  Brand
# 0              95909  Apple iPhone SE (White, 256 GB) (Includes EarP...  Apple
# 1              95909                    APPLE iPhone SE (Black, 128 GB)  Apple
# 2              95909                      APPLE iPhone SE (Red, 128 GB)  Apple
# 3              95909                     APPLE iPhone SE (Black, 64 GB)  Apple
# 4              95807                     APPLE iPhone SE (White, 64 GB)  Apple

# %% [markdown]
# ### Least Numbers of Rating

# %%
df[["Number Of Ratings","Product Name","Brand"]].sort_values(ascending=True,by="Number Of Ratings",ignore_index=True)[:5]
# Out:
#    Number Of Ratings                                Product Name  Brand
# 0                542        APPLE iPhone 12 Pro (Silver, 512 GB)  Apple
# 1                545      APPLE iPhone 12 Pro (Graphite, 128 GB)  Apple
# 2                545      APPLE iPhone 12 Pro (Graphite, 256 GB)  Apple
# 3                545  APPLE iPhone 12 Pro (Pacific Blue, 128 GB)  Apple
# 4                545  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)  Apple

# %%
Star Rating

# %% [markdown]
# ### Highest Star Rating

# %%
df[["Star Rating","Product Name","Upc"]].sort_values(ascending=False,by="Star Rating",ignore_index=True)[:10]
# Out:
#    Star Rating                                      Product Name  \
# 0          4.7   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 1          4.7       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 2          4.7  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 3          4.7             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 4          4.7            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 5          4.6                 APPLE iPhone 8 Plus (Gold, 64 GB)
# 6          4.6                   APPLE iPhone 12 (White, 128 GB)
# 7          4.6        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 8          4.6                   APPLE iPhone 12 (Black, 128 GB)
# 9          4.6                    APPLE iPhone 12 (Blue, 128 GB)
#
#                 Upc
# 0  MOBFKCTSRYPAQNYT
# 1  MOBFKCTSKDMKCGQS
# 2  MOBFKCTSCAAKGQV7
# 3  MOBFKCTSAPAYNSGG
# 4  MOBFKCTS7HCHSPFH
# 5  MOBEXRGV7EHHTGUH
# 6  MOBFWBYZBTZFGJF9
# 7  MOBFWBYZFDGQSDWS
# 8  MOBFWBYZK3HACR72
# 9  MOBFWBYZKPTZF9VG

# %% [markdown]
# ### Least Star Rating

# %%
df[["Star Rating","Product Name","Upc"]].sort_values(ascending=True,by="Star Rating",ignore_index=True)[:10]
# Out:
#    Star Rating                                       Product Name  \
# 0          4.5             APPLE iPhone 12 Pro (Graphite, 128 GB)
# 1          4.5                  APPLE iPhone 12 Mini (Red, 64 GB)
# 2          4.5                APPLE iPhone 12 Mini (White, 64 GB)
# 3          4.5             APPLE iPhone 12 Pro (Graphite, 256 GB)
# 4          4.5               APPLE iPhone 12 Mini (White, 128 GB)
# 5          4.5               APPLE iPhone 12 Pro (Silver, 512 GB)
# 6          4.5  Apple iPhone SE (White, 256 GB) (Includes EarP...
# 7          4.5         APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 8          4.5                APPLE iPhone 12 Mini (Black, 64 GB)
# 9          4.5               APPLE iPhone 12 Mini (Black, 128 GB)
#
#                 Upc
# 0  MOBFWBYZBZ7Y56WD
# 1  MOBFWBYZNVWGWN2U
# 2  MOBFWBYZBH4CEC4C
# 3  MOBFWBYZBA36UB7G
# 4  MOBFWBYZAGXJRDGB
# 5  MOBFWBYZ5UY6ZBVA
# 6  MOBFRFXHPZCHAPEH
# 7  MOBFWBYZTHSXKMGW
# 8  MOBFWBYZXSEGBS6F
# 9  MOBFWBYZH2AMPNPD

# %% [markdown]
# ### The Higest Rating

# %%
df["Number Of Ratings"].max()
# Out:
# 95909

# %% [markdown]
# ### Higest Sale Price

# %%
df[["Sale Price","Product Name","Number Of Reviews"]].sort_values(ascending=False,by="Sale Price",ignore_index=True)[:10]
# Out:
#    Sale Price                                      Product Name  \
# 0      140900        APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
# 1      140900              APPLE iPhone 12 Pro (Silver, 512 GB)
# 2      131900  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 3      131900            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 4      130900        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 5      130900    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 6      130900          APPLE iPhone 12 Pro Max (Silver, 256 GB)
# 7      130900            APPLE iPhone 12 Pro Max (Gold, 256 GB)
# 8      120900            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 9      120900        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
#
#    Number Of Reviews
# 0                 42
# 1                 42
# 2                101
# 3                101
# 4                 45
# 5                 45
# 6                 45
# 7                 45
# 8                 42
# 9                 45

# %% [markdown]
# ### Least Sale Price

# %%
df[["Sale Price","Product Name","Number Of Reviews"]].sort_values(ascending=True,by="Sale Price",ignore_index=True)[:10]
# Out:
#    Sale Price                                       Product Name  \
# 0       29999                     APPLE iPhone SE (Black, 64 GB)
# 1       29999                     APPLE iPhone SE (White, 64 GB)
# 2       34999                      APPLE iPhone SE (Red, 128 GB)
# 3       34999                    APPLE iPhone SE (White, 128 GB)
# 4       34999                    APPLE iPhone SE (Black, 128 GB)
# 5       39999  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 6       41999  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 7       41999  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 8       41999  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 9       41999  Apple iPhone XR (White, 128 GB) (Includes EarP...
#
#    Number Of Reviews
# 0               8161
# 1               8154
# 2               8161
# 3               8154
# 4               8161
# 5               6796
# 6               6796
# 7               6804
# 8               6796
# 9               6796

# %% [markdown]
# ###  Higest Discount Percentage

# %%
df[["Discount Percentage","Product Name","Number Of Reviews"]].sort_values(ascending=False,by="Discount Percentage",ignore_index=True)[:10]
# Out:
#    Discount Percentage                                       Product Name  \
# 0                   29        APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 1                   24                     APPLE iPhone SE (White, 64 GB)
# 2                   24                     APPLE iPhone SE (Black, 64 GB)
# 3                   22                      APPLE iPhone SE (Red, 128 GB)
# 4                   22                    APPLE iPhone SE (White, 128 GB)
# 5                   22                    APPLE iPhone SE (Black, 128 GB)
# 6                   20  Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 7                   20  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 8                   20  Apple iPhone XR (Black, 128 GB) (Includes EarP...
# 9                   20  Apple iPhone XR (White, 128 GB) (Includes EarP...
#
#    Number Of Reviews
# 0                523
# 1               8154
# 2               8161
# 3               8161
# 4               8154
# ...

# %% [markdown]
# ### Least Discount Percentage

# %%
df[["Discount Percentage","Product Name","Number Of Reviews"]].sort_values(ascending=True,by="Discount Percentage",ignore_index=True)[:10]
# Out:
#    Discount Percentage                                      Product Name  \
# 0                    0                 APPLE iPhone 8 Plus (Gold, 64 GB)
# 1                    0             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 2                    0            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 3                    0   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 4                    0  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 5                    0               APPLE iPhone 8 (Space Grey, 256 GB)
# 6                    0               APPLE iPhone XS Max (Silver, 64 GB)
# 7                    0               APPLE iPhone 8 Plus (Silver, 64 GB)
# 8                    0                     APPLE iPhone 8 (Gold, 256 GB)
# 9                    0                   APPLE iPhone 8 (Silver, 256 GB)
#
#    Number Of Reviews
# 0                356
# 1                101
# 2                101
# 3                101
# 4                101
# 5                794
# ...
